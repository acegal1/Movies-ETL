# %%
#
import pandas as pd

# %%
#use the pandas read to create a dataframe varible for both 
# may get an error that movies_metadata has a column with mix datatypes can ignore by adding ,low_memory=False)
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
# view files () default is to show 5 records
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
#view files
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
#get sample of data  use    df for dataframe df.sample(n=5)
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 8326293    85855      661     3.0   988611588
# 23905998  248242     3489     2.0  1001105724
# 19671518  204339    27713     3.0  1421368064
# 23008932  238958    74946     3.0  1455294459
# 19597305  203580     4321     2.0  1019859256

# %%
movies_metadata.sample(n=5)
# Out:
#        adult                              belongs_to_collection    budget  \
# 5299   False                                                NaN         0
# 28075  False  {'id': 168880, 'name': 'Beethoven Collection',...         0
# 7112   False                                                NaN  15000000
# 5443   False                                                NaN         0
# 35340  False  {'id': 185667, 'name': 'The Complete Monterey ...         0
#
#                                                   genres homepage     id  \
# 5299                      [{'id': 27, 'name': 'Horror'}]      NaN  17898
# 28075  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...      NaN  78080
# 7112   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN   1278
# 5443   [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...      NaN  87481
# 35340                   [{'id': 10402, 'name': 'Music'}]      NaN  26028
#
#          imdb_id original_language                   original_title  \
# ...
